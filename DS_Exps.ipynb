# %% [markdown]
# # **Experiment 1**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv("student_info.csv");
df1
# Out:
#    Student ID     Name  Age Grade
# 0         101    Alice   20     A
# 1         102      Bob   21     B
# 2         103  Charlie   19     A
# 3         104    David   22     C
# 4         105      Eve   20     B

# %%
df2 = pd.read_csv("student_scores.csv");
df2
# Out:
#    Student ID  Math Score  English Score  Science Score
# 0         101          85             78             92
# 1         102          76             88             81
# 2         103          90             95             89
# 3         104          65             70             75
# 4         105          80             82             87

# %%
df3 = pd.concat([df1,df2],axis = 1);
df3
# Out:
#    Student ID     Name  Age Grade  Student ID  Math Score  English Score  \
# 0         101    Alice   20     A         101          85             78
# 1         102      Bob   21     B         102          76             88
# 2         103  Charlie   19     A         103          90             95
# 3         104    David   22     C         104          65             70
# 4         105      Eve   20     B         105          80             82
#
#    Science Score
# 0             92
# 1             81
# 2             89
# 3             75
# 4             87

# %% [markdown]
# # **Experiment 2**

# %%
df = pd.read_csv("grapes_new.csv");
df
# Out:
#      COLOR_INTENSITY       SHAPE  RIPENESS_PER  ALCOHOL_PER  MALIC_ACID_PER  \
# 0             120.53  elliptical         16.73        14.23            1.71
# 1             112.57  elliptical         20.30        13.20            1.78
# 2             120.78  elliptical         20.81        13.16            2.36
# 3             134.17  elliptical         19.47        14.37            1.95
# 4             112.19       round         17.57        13.24            2.59
# ..               ...         ...           ...          ...             ...
# 189           102.34  elliptical         21.23        12.07            2.16
# 190           109.80  elliptical         21.67        12.43            1.53
# 191           103.86       round         22.01        11.79            2.13
# 192            98.30  elliptical         21.95        12.37            1.63
# 193           101.33  elliptical         21.60        12.04            4.30
#
# ...

# %%
df.head()
#displaying first few rows of the dataset
# Out:
#    COLOR_INTENSITY       SHAPE  RIPENESS_PER  ALCOHOL_PER  MALIC_ACID_PER  \
# 0           120.53  elliptical         16.73        14.23            1.71
# 1           112.57  elliptical         20.30        13.20            1.78
# 2           120.78  elliptical         20.81        13.16            2.36
# 3           134.17  elliptical         19.47        14.37            1.95
# 4           112.19       round         17.57        13.24            2.59
#
#     ASH  ALCALINITY_OF_ASH  MAGNESIUM_MEASURE  TOTAL_PHENOLS  FLAVANOIDS  ...  \
# 0  2.43               15.6                127           2.80        3.06  ...
# 1  2.14               11.2                100           2.65        2.76  ...
# 2  2.67               18.6                101           2.80        3.24  ...
# 3  2.50               16.8                113           3.85        3.49  ...
# 4  2.87               21.0                118           2.80        2.69  ...
#
# ...

# %%
df.tail()
#displaying last few rows of the dataset
# Out:
#      COLOR_INTENSITY       SHAPE  RIPENESS_PER  ALCOHOL_PER  MALIC_ACID_PER  \
# 187           101.33  elliptical         22.16        13.05            5.80
# 188           102.60  elliptical         21.78        11.87            4.31
# 189           102.34  elliptical         21.23        12.07            2.16
# 191           103.86       round         22.01        11.79            2.13
# 192            98.30  elliptical         21.95        12.37            1.63
#
#       ASH  ALCALINITY_OF_ASH  MAGNESIUM_MEASURE  TOTAL_PHENOLS  FLAVANOIDS  \
# 187  2.13               21.5                 86           2.62        2.65
# 188  2.39               21.0                 82           2.86        3.03
# 189  2.17               21.0                 85           2.60        2.65
# 191  2.78               28.5                 92           2.13        2.24
# 192  2.30               24.5                 88           2.22        2.45
#
# ...

# %%
df.describe(include = "all")
#displays summary statistics of the dataset
# Out:
#         COLOR_INTENSITY       SHAPE  RIPENESS_PER  ALCOHOL_PER  \
# count        177.000000         177    177.000000   177.000000
# unique              NaN           2           NaN          NaN
# top                 NaN  elliptical           NaN          NaN
# freq                NaN         110           NaN          NaN
# mean         116.945650         NaN     21.578023    13.013446
# std           14.534378         NaN      2.358490     0.810013
# min           93.000000         NaN     16.170000    11.030000
# 25%          105.440000         NaN     20.550000    12.360000
# 50%          115.230000         NaN     21.860000    13.050000
# 75%          124.060000         NaN     23.360000    13.670000
# max          167.000000         NaN     25.200000    14.830000
#
#         MALIC_ACID_PER         ASH  ALCALINITY_OF_ASH  MAGNESIUM_MEASURE  \
# count       177.000000  177.000000         177.000000         177.000000
# ...

# %%
df.info()
#displays info about data types and missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 177 entries, 0 to 192
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   COLOR_INTENSITY    177 non-null    float64
#  1   SHAPE              177 non-null    object
#  2   RIPENESS_PER       177 non-null    float64
#  3   ALCOHOL_PER        177 non-null    float64
#  4   MALIC_ACID_PER     177 non-null    float64
#  5   ASH                177 non-null    float64
#  6   ALCALINITY_OF_ASH  177 non-null    float64
#  7   MAGNESIUM_MEASURE  177 non-null    int64
#  8   TOTAL_PHENOLS      177 non-null    float64
#  9   FLAVANOIDS         177 non-null    float64
#  10  PROANTHOCYANINS    177 non-null    float64
#  11  HUE                177 non-null    float64
#  12  PROLINE            177 non-null    int64
#  13  TEMPERATURE        177 non-null    float64
#  14  AVG_HUMIDITY       177 non-null    float64
#  15  FERT_NITRO_PER     177 non-null    float64
# ...

# %% [markdown]
# #Handling Null Values

# %%
df.isnull().sum()
#displays the number of missing values in each column
# Out:
# COLOR_INTENSITY      0
# SHAPE                0
# RIPENESS_PER         2
# ALCOHOL_PER          3
# MALIC_ACID_PER       0
# ASH                  0
# ALCALINITY_OF_ASH    6
# MAGNESIUM_MEASURE    0
# TOTAL_PHENOLS        0
# FLAVANOIDS           0
# PROANTHOCYANINS      0
# HUE                  2
# PROLINE              0
# TEMPERATURE          0
# AVG_HUMIDITY         0
# FERT_NITRO_PER       0
# WATER_O2_PER         4
# WATER_PH             0
# FER_P2O5_PER         0
# SOIL_TYPE            0
# CLASS                0
# dtype: int64

# %%
df = df.dropna()
#drops the rows with missing values

# %%
df.isnull().sum()
#checking if null values still remain
# Out:
# COLOR_INTENSITY      0
# SHAPE                0
# RIPENESS_PER         0
# ALCOHOL_PER          0
# MALIC_ACID_PER       0
# ASH                  0
# ALCALINITY_OF_ASH    0
# MAGNESIUM_MEASURE    0
# TOTAL_PHENOLS        0
# FLAVANOIDS           0
# PROANTHOCYANINS      0
# HUE                  0
# PROLINE              0
# TEMPERATURE          0
# AVG_HUMIDITY         0
# FERT_NITRO_PER       0
# WATER_O2_PER         0
# WATER_PH             0
# FER_P2O5_PER         0
# SOIL_TYPE            0
# CLASS                0
# dtype: int64

# %% [markdown]
# #Removing Outliers

# %%
#finding the 25 and 75 percentile
numeric_df = df.select_dtypes(include=[np.number])
Q1 = numeric_df.quantile(0.25)
Q3 = numeric_df.quantile(0.75)
IQR = Q3 - Q1

# %%
#Specifying bounds for Outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
#Removing and checking for removed outliers
clean_df = df[~((numeric_df < lower_bound) | (numeric_df > upper_bound)).any(axis=1)]
clean_df
# Out:
#      COLOR_INTENSITY       SHAPE  RIPENESS_PER  ALCOHOL_PER  MALIC_ACID_PER  \
# 0             120.53  elliptical         16.73        14.23            1.71
# 1             112.57  elliptical         20.30        13.20            1.78
# 2             120.78  elliptical         20.81        13.16            2.36
# 3             134.17  elliptical         19.47        14.37            1.95
# 4             112.19       round         17.57        13.24            2.59
# ..               ...         ...           ...          ...             ...
# 183           118.07  elliptical         19.79        14.39            1.87
# 186           130.51  elliptical         16.87        13.86            1.35
# 188           102.60  elliptical         21.78        11.87            4.31
# 189           102.34  elliptical         21.23        12.07            2.16
# 192            98.30  elliptical         21.95        12.37            1.63
#
# ...
